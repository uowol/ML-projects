# %% [markdown]
# <a href="https://colab.research.google.com/github/uowol/ML-projects/blob/main/CLIP_ALL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # data collect

# %%
# !pip install pytorch pytorch==1.7.1 torchvision cudatoolkit==11.0
# !pip install ftfy regex tqdm
# !pip install git+https://github.com/openai/CLIP.git
# !pip install deeplake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ftfy in /usr/local/lib/python3.9/dist-packages (6.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (4.65.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy) (0.2.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-mlnyk_fc
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-mlnyk_fc
#   Resolved https://github.com/openai/CLIP.git to commit a9b1bf5920416aaeaec965c25dd9e8f98c864f16
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.9/dist-packages (from clip==1.0) (6.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from clip==1.0) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from clip==1.0) (4.65.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from clip==1.0) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from clip==1.0) (0.14.1+cu116)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->clip==1.0) (0.2.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->clip==1.0) (4.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->clip==1.0) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision->clip==1.0) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision->clip==1.0) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->clip==1.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->clip==1.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->clip==1.0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->clip==1.0) (4.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deeplake in /usr/local/lib/python3.9/dist-packages (3.2.15)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from deeplake) (8.1.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from deeplake) (8.4.0)
# Requirement already satisfied: humbug>=0.2.6 in /usr/local/lib/python3.9/dist-packages (from deeplake) (0.2.8)
# Requirement already satisfied: hub>=2.8.7 in /usr/local/lib/python3.9/dist-packages (from deeplake) (3.0.1)
# Requirement already satisfied: pathos in /usr/local/lib/python3.9/dist-packages (from deeplake) (0.3.0)
# Requirement already satisfied: pyjwt in /usr/local/lib/python3.9/dist-packages (from deeplake) (2.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from deeplake) (4.65.0)
# Requirement already satisfied: numcodecs in /usr/local/lib/python3.9/dist-packages (from deeplake) (0.11.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.9/dist-packages (from deeplake) (1.26.89)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from deeplake) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from humbug>=0.2.6->deeplake) (2.25.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.89 in /usr/local/lib/python3.9/dist-packages (from boto3->deeplake) (1.29.89)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from boto3->deeplake) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from boto3->deeplake) (0.6.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from numcodecs->deeplake) (0.4)
# Requirement already satisfied: multiprocess>=0.70.14 in /usr/local/lib/python3.9/dist-packages (from pathos->deeplake) (0.70.14)
# Requirement already satisfied: pox>=0.3.2 in /usr/local/lib/python3.9/dist-packages (from pathos->deeplake) (0.3.2)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.9/dist-packages (from pathos->deeplake) (0.3.6)
# Requirement already satisfied: ppft>=1.7.6.6 in /usr/local/lib/python3.9/dist-packages (from pathos->deeplake) (1.7.6.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.9/dist-packages (from botocore<1.30.0,>=1.29.89->boto3->deeplake) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.9/dist-packages (from botocore<1.30.0,>=1.29.89->boto3->deeplake) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->humbug>=0.2.6->deeplake) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->humbug>=0.2.6->deeplake) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->humbug>=0.2.6->deeplake) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.89->boto3->deeplake) (1.15.0)

# %%
import deeplake
from torchvision import transforms, models

ds_train = deeplake.load('hub://activeloop/pacs-train')
ds_test = deeplake.load('hub://activeloop/pacs-test')
# Out:
# hub://activeloop/pacs-train loaded successfully.
#
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/pacs-train
#
# hub://activeloop/pacs-test loaded successfully.
#
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/pacs-test

# %%
import torch
from torch import nn 
from torch.utils.data import DataLoader

import clip

device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)

# %%
def get_image_features(clip_model, images):
    num_image_layer = clip_model.visual.transformer.layers
    images = images.to(device)

    out_list = []
    x = clip_model.visual.conv1(images.type(clip_model.dtype))
    x = x.reshape(x.shape[0], x.shape[1], -1)   # shape = [*, width, grid ** 2]
    x = x.permute(0, 2, 1)                      # shape = [*, grid ** 2, width]
    x = torch.cat([clip_model.visual.class_embedding.to(x.dtype) + 
                   torch.zeros(x.shape[0], 1, x.shape[-1], dtype=x.dtype, device=x.device), x], dim=1)  # shape = [*, grid ** 2 + 1, width]
    x = x + clip_model.visual.positional_embedding.to(x.dtype)
    x = clip_model.visual.ln_pre(x)
    x = x.permute(1, 0, 2)          # NLD -> LND

    for i in range(num_image_layer):
        x = clip_model.visual.transformer.resblocks[i](x)
        tmp = x.permute(1, 0, 2)    # LND -> NLD
        tmp = tmp[:, 0, :].detach()
        out_list.append(tmp)

    image_features = torch.stack(out_list)

    return image_features

def get_text_features(clip_model, texts):
    num_text_layer = clip_model.transformer.layers
    texts = texts.to(device)

    out_list = []
    x = clip_model.token_embedding(texts).type(clip_model.dtype)  # [batch_size, n_ctx, d_clip_model]
    x = x + clip_model.positional_embedding.type(clip_model.dtype)
    x = x.permute(1, 0, 2)                  # NLD -> LND

    for i in range(num_text_layer):
        x = clip_model.transformer.resblocks[i](x)
        tmp = x.permute(1, 0, 2).detach()   # LND -> NLD
        out_list.append(tmp)

    text_features = torch.stack(out_list)

    return text_features

# %%
def get_image_features_and_labels(data_loader):
    image_features_list = []
    labels_list = []

    for i, data in enumerate(data_loader):
        images = data['images']
        labels = torch.squeeze(data['labels'])

        images = images.to(device)
        labels = labels.to(device)

        image_features = get_image_features(clip_model, images)
        
        labels_list.append(labels)
        image_features_list.append(image_features)
    
    return image_features_list, labels_list

# %%
batch_size = 32
tform = transforms.Compose([
    # transforms.RandomRotation(20), # Image augmentation
    transforms.ToTensor(), # Must convert to pytorch tensor for subsequent operations to run
    # transforms.Normalize([0.5], [0.5]),
])

train_loader = ds_train.pytorch(num_workers = 0, shuffle = True, 
                                transform = {'images': tform, 'labels': None}, 
                                batch_size = batch_size, decode_method = {'images': 'pil'})
test_loader = ds_test.pytorch(num_workers = 0, transform = {'images': tform, 'labels': None}, 
                                batch_size = batch_size, decode_method = {'images': 'pil'})

# %%
train_image_features_list, train_labels_list = get_image_features_and_labels(train_loader)
test_image_features_list, test_labels_list = get_image_features_and_labels(test_loader)

# %%
import pickle

## save pickle
with open('train_image_features_list.pickle', 'wb') as fw: 
    pickle.dump(train_image_features_list, fw)
with open('train_labels_list.pickle', 'wb') as fw:
    pickle.dump(train_labels_list, fw)
with open('test_image_features_list.pickle', 'wb') as fw:
    pickle.dump(test_image_features_list, fw)
with open('test_labels_list.pickle', 'wb') as fw:
    pickle.dump(test_labels_list, fw)

# %%
def save_images(data_loader, split=1, type='train'):
    images_list = []
    labels_list = []
    save_idx = 0
    size = int(len(data_loader)/split)

    for i, data in enumerate(data_loader):
        images = data['images']
        images = images.to(device)

        labels = torch.squeeze(data['labels'])
        labels = labels.to(device)
        
        images_list.append(images)
        labels_list.append(labels)
        
        if (i+1) % size == 0:
            with open(f'{type}_images_list{save_idx}.pickle', 'wb') as fw: 
                pickle.dump(images_list, fw)
            images_list = []
            save_idx += 1

    with open(f'{type}_images_list{save_idx}.pickle', 'wb') as fw: 
        pickle.dump(images_list, fw)
    
    return labels_list

def load_images_list(type='train', i=0):
    with open(f'{type}_images_list{i}.pickle', 'rb') as fr: 
        images_list = pickle.load(fr)
    return images_list

# %%
train_labels_list = save_images(train_loader, type="train", split=3)

with open('train_labels_list0.pickle', 'wb') as fw:
    pickle.dump(train_labels_list, fw)

test_labels_list = save_images(test_loader, type="test", split=3)

with open('test_labels_list0.pickle', 'wb') as fw:
    pickle.dump(test_labels_list, fw)

# %%
pacs_class = [
    'a dog', 'an elephant', 'a giraffe', 'a guitar', 'a horse', 'a house', 'a person'
]

def prompt(idx):
    return f"An image of {pacs_class[idx]}"

prompts = [prompt(x) for x in range(7)]
print(prompts)
# Out:
# ['An image of a dog', 'An image of an elephant', 'An image of a giraffe', 'An image of a guitar', 'An image of a horse', 'An image of a house', 'An image of a person']

# %%
class_tokens = clip.tokenize([prompt(x) for x in range(7)]).to(device)
with open('class_tokens.pickle', 'wb') as fw:
    pickle.dump(class_tokens, fw)

# %%
class_features = get_text_features(clip_model, class_tokens)
with open('class_features.pickle', 'wb') as fw:
    pickle.dump(class_features, fw)

# %%
def get_images_feature(clip_model, images):
    images = images.to(device)

    x = clip_model.visual.conv1(images.type(clip_model.dtype))
    x = x.reshape(x.shape[0], x.shape[1], -1)   # shape = [*, width, grid ** 2]
    x = x.permute(0, 2, 1)                      # shape = [*, grid ** 2, width]
    x = torch.cat([clip_model.visual.class_embedding.to(x.dtype) + 
                   torch.zeros(x.shape[0], 1, x.shape[-1], dtype=x.dtype, device=x.device), x], dim=1)  # shape = [*, grid ** 2 + 1, width]
    x = x + clip_model.visual.positional_embedding.to(x.dtype)
    x = clip_model.visual.ln_pre(x)
    x = x.permute(1, 0, 2)  # NLD -> LND
    x = clip_model.visual.transformer(x)
    x = x.permute(1, 0, 2)  # LND -> NLD
    x = x[:, 0, :].detach()

    return x

# %%
def get_texts_feature(clip_model, texts):
    texts = texts.to(device)

    x = clip_model.token_embedding(texts).type(clip_model.dtype)  # [batch_size, n_ctx, d_clip_model]
    x = x + clip_model.positional_embedding.type(clip_model.dtype)
    x = x.permute(1, 0, 2)            # NLD -> LND
    x = clip_model.transformer(x)
    x = x.permute(1, 0, 2).detach()   # LND -> NLD

    return x

# %%
def get_images_feature_and_labels(data_loader):
    images_feature_list = []
    labels_list = []

    for i, data in enumerate(data_loader):
        images = data['images']
        labels = torch.squeeze(data['labels'])

        images = images.to(device)
        labels = labels.to(device)

        images_features = get_images_feature(clip_model, images)
        
        labels_list.append(labels)
        images_feature_list.append(images_features)
    
    return images_feature_list, labels_list

# %%
train_images_feature_list, train_labels_list0 = get_images_feature_and_labels(train_loader)
test_images_feature_list, test_labels_list0 = get_images_feature_and_labels(test_loader)

# %%
## save pickle
with open('train_images_feature_list.pickle', 'wb') as fw: 
    pickle.dump(train_images_feature_list, fw)
with open('train_labels_list0.pickle', 'wb') as fw:
    pickle.dump(train_labels_list0, fw)
with open('test_images_feature_list.pickle', 'wb') as fw:
    pickle.dump(test_images_feature_list, fw)
with open('test_labels_list0.pickle', 'wb') as fw:
    pickle.dump(test_labels_list0, fw)

# %%
class_features0 = get_texts_feature(clip_model, class_tokens)
with open('class_features0.pickle', 'wb') as fw:
    pickle.dump(class_features0, fw)

# %% [markdown]
# # data load

# %%
## load pickle
with open('class_tokens.pickle', 'rb') as fr:
    class_tokens = pickle.load(fr)
with open('class_features.pickle', 'rb') as fr:
    class_features = pickle.load(fr)
with open('train_image_features_list.pickle', 'rb') as fr:
    train_image_features_list = pickle.load(fr)
with open('train_labels_list.pickle', 'rb') as fr:
    train_labels_list = pickle.load(fr)
with open('test_image_features_list.pickle', 'rb') as fr:
    test_image_features_list = pickle.load(fr)
with open('test_labels_list.pickle', 'rb') as fr:
    test_labels_list = pickle.load(fr)

# %% [markdown]
# # Model constructing

# %%
import pandas as pd
import numpy as np

import torch
from torch import nn 
from torch.utils.data import DataLoader

from torchvision import datasets, transforms, models
from torchvision.transforms import ToTensor

import clip

# %%
class OurCLIP(nn.Module):        
    def __init__(self, clip_model, # use pre-trained clip model
                 use_one_ln1=True, use_one_ln2=True, 
                 use_one_projection1=True, use_one_projection2=True,
                 projection_random_init1=False, 
                 projection_random_init2=False, 
                 trainable_ln1=False, trainable_ln2=False, 
                 trainable_projection1=False, trainable_projection2=False,
                 threshold = 100, score_type=0): 
        super().__init__()

        self.dtype = clip_model.dtype
        self.threshold = threshold
        self.score_type = score_type

        self.threshold_weight = nn.Parameter(torch.rand(1)).requires_grad_(True)

        ####################### 미구현
        if use_one_ln1:
            self.ln_post = clip_model.visual.ln_post.requires_grad_(trainable_ln1)
        else: pass
        if use_one_ln2:
            self.ln_final = clip_model.ln_final.requires_grad_(trainable_ln2)
        else: pass
        ########################

        if use_one_projection1:
            self.visual_projection = nn.Parameter(clip_model.visual.proj.clone().detach()).requires_grad_(trainable_projection1)
        else:
            if projection_random_init1:
                self.visual_projection = nn.Parameter(
                    torch.stack([
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.visual.proj, dtype=torch.float16).normal_(mean=0,std=0.03),
                        clip_model.visual.proj.clone().detach()
                    ])).requires_grad_(trainable_projection1)
            else:
                self.visual_projection = nn.Parameter(
                    torch.stack([
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach(),
                        clip_model.visual.proj.clone().detach()
                    ])).requires_grad_(trainable_projection1)
        
        if use_one_projection2:
            self.textual_projection = nn.Parameter(clip_model.text_projection.clone().detach()).requires_grad_(trainable_projection2)
        else:
            if projection_random_init2:
                self.textual_projection = nn.Parameter(
                    torch.stack([
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        torch.zeros_like(clip_model.text_projection, dtype=torch.float16).normal_(mean=0,std=0.03),
                        clip_model.text_projection.clone().detach()
                    ])).requires_grad_(trainable_projection2)
            else:
                self.textual_projection = nn.Parameter(
                    torch.stack([
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach(),
                        clip_model.text_projection.clone().detach()
                    ])).requires_grad_(trainable_projection2)


    def forward(self, image_features, class_features, class_tokens):    
        image_features2 = self.ln_post(image_features)                      # (12, batch_size, 768)
        image_embeddings = image_features2 @ self.visual_projection         # (12, batch_size, 512)  <- we'll use it

        class_features2 = self.ln_final(class_features).type(self.dtype)    # (12, seq_len, 77, 512)
        class_embeddings = class_features2[:, torch.arange(class_features2.shape[1]), 
                                           class_tokens.argmax(dim=-1)] @ self.textual_projection
                                                                            # (12, seq_len, 512)  <- we'll use it

        score_tensor = torch.einsum("ijk,mnk->jnim",image_embeddings, class_embeddings)
        if self.score_type != 3:
            score_tensor = score_tensor.reshape(*score_tensor.shape[:2],-1)

        if self.score_type == 1:
            return torch.mean(score_tensor, dim=-1)
        if self.score_type == 2:
            return torch.sigmoid(100 * (score_tensor-(self.threshold*self.threshold_weight))).sum(dim=-1)
        if self.score_type == 3:
            return score_tensor.max(dim=-1)[0].mean(dim=-1)
        return torch.max(score_tensor, dim=-1)[0]

# %% [markdown]
# # Train

# %%
import time
import torch.nn.functional as f

def train_one_epoch(model, optimizer, criterion, image_features_list, labels_list, max_iter_num=3000, print_log=True):

    model.train()

    # Zero the performance stats for each epoch
    running_loss = 0.0
    start_time = time.time()
    total = 0
    correct = 0
    
    for i in range(len(image_features_list)):
        image_features = image_features_list[i]
        labels = labels_list[i]
        
        optimizer.zero_grad()
        
        output = model(image_features, class_features, class_tokens)

        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        
        predicted = torch.argmax(output, dim=-1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
    
        # Print performance statistics
        running_loss += loss.item()

        if print_log:
            if i != 0 and i % 10 == 0:    # print every 10 batches
                batch_time = time.time()
                speed = (i+1)/(batch_time-start_time)
                print('[%5d] loss: %.3f, speed: %.2f, accuracy: %.2f %%' % (i, running_loss, speed, accuracy))

                running_loss = 0.0
                total = 0
                correct = 0

        if i != 0 and i % max_iter_num == 0:
            break;
    
    return accuracy

    
def test_model(model, image_features_list, labels_list, max_iter_num=1000, print_log=True):

    model.eval()

    start_time = time.time()
    total = 0
    correct = 0
    with torch.no_grad():
        for i in range(len(image_features_list)):
            image_features = image_features_list[i]
            labels = labels_list[i]

            # forward + backward + optimize
            output = model(image_features, class_features, class_tokens)

            predicted = torch.argmax(output, dim=-1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
            if i != 0 and i % max_iter_num == 0:
                break
            
        accuracy = 100 * correct / total

        if print_log:
            print('Finished Testing')
            print('Testing accuracy: %.1f %%' %(accuracy))
            
    return accuracy

# %%
class EarlyStopping:
    def __init__(self, patience=5):
        self.accuracy = 0
        self.patience = 0
        self.patience_limit = patience
        
    def step(self, accuracy):
        if self.accuracy < accuracy:
            self.accuracy = accuracy
            self.patience = 0
        else:
            self.patience += 1
    
    def is_stop(self):
        return self.patience >= self.patience_limit

# %%
def start_train(model, criterion, optimizer, num_epochs=200, patience=5, 
                save_path='output0316.txt', save_content='', print_log=True):
    device = "cuda" if torch.cuda.is_available() else "cpu"

    early_stop = EarlyStopping(patience)

    for epoch in range(num_epochs):  # loop over the dataset multiple times
        print("------------------ Training Epoch {} ------------------".format(epoch+1))
        train_accuracy = train_one_epoch(model, optimizer, criterion, 
                                        train_image_features_list, train_labels_list, max_iter_num=1000, print_log=print_log)
        test_accuracy = test_model(model, test_image_features_list, test_labels_list, print_log=print_log)
        print(f"train accuracy: {train_accuracy:.2f}%\ttest accuracy: {test_accuracy:.2f}%")

        early_stop.step(test_accuracy)
        if early_stop.is_stop():
            print(f"-\ntrain epoch: {epoch}")
            break

    with open(save_path, 'a') as f:
        f.write(f"{epoch+1}\t"+"="*10+f"{save_content}\n")
        f.write(f"accuracy: {test_accuracy:.4f}\n")


    print('Finished Training')

# %% [markdown]
# # inference

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)

num_epochs = 400
patience = 5

# %%
# train all by one tensor / max_score
model = OurCLIP(clip_model, 
                trainable_projection1=True, trainable_projection2=True,
                score_type=0).to(device)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.1)

start_train(model, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='train all by one tensor / max_score', print_log=False)

torch.save(model.state_dict(), 'saved/oneMaxModel.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 96.52%	test accuracy: 95.71%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 97.67%	test accuracy: 95.71%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 98.06%	test accuracy: 95.43%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 98.24%	test accuracy: 95.18%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 98.34%	test accuracy: 94.82%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 98.50%	test accuracy: 94.66%
# -
# train epoch: 5
# Finished Training

# %%
# train all by one tensor / new_score
# reference: https://discuss.pytorch.org/t/is-there-any-soft-way-of-counting-positive-values-with-grad-reserved/158975/2
clip_model, preprocess = clip.load("ViT-B/32", device=device)
model = OurCLIP(clip_model, 
                trainable_projection1=True, trainable_projection2=True,
                score_type=3).to(device)

# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print(name, param.shape)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.1)

start_train(model, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='train all by one tensor / new_score', print_log=False)

torch.save(model.state_dict(), 'saved/oneNewModel.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 82.79%	test accuracy: 47.95%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 92.71%	test accuracy: 54.07%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 94.58%	test accuracy: 78.14%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 95.51%	test accuracy: 85.20%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 95.98%	test accuracy: 89.18%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 96.27%	test accuracy: 90.60%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 96.49%	test accuracy: 91.45%
# ------------------ Training Epoch 8 ------------------
# train accuracy: 96.64%	test accuracy: 91.64%
# ------------------ Training Epoch 9 ------------------
# train accuracy: 96.79%	test accuracy: 91.70%
# ------------------ Training Epoch 10 ------------------
# train accuracy: 96.93%	test accuracy: 91.73%
# ------------------ Training Epoch 11 ------------------
# train accuracy: 97.04%	test accuracy: 91.71%
# ------------------ Training Epoch 12 ------------------
# train accuracy: 97.11%	test accuracy: 91.66%
# ------------------ Training Epoch 13 ------------------
# train accuracy: 97.18%	test accuracy: 91.63%
# ------------------ Training Epoch 14 ------------------
# train accuracy: 97.32%	test accuracy: 91.54%
# ------------------ Training Epoch 15 ------------------
# train accuracy: 97.36%	test accuracy: 91.55%
# -
# train epoch: 14
# Finished Training

# %%
# train all by each tensor(init with last weight) / max_score
clip_model, preprocess = clip.load("ViT-B/32", device=device)
model = OurCLIP(clip_model, 
                use_one_projection1=False, use_one_projection2=False,
                trainable_projection1=True, trainable_projection2=True,
                score_type=0).to(device)

# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print(name, param.shape)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.1)

start_train(model, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='train all by each tensor(init with last weight) / max_score',
            print_log=False)

torch.save(model.state_dict(), 'saved/allMaxModel.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 96.45%	test accuracy: 95.67%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 97.67%	test accuracy: 95.75%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 98.05%	test accuracy: 95.49%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 98.26%	test accuracy: 95.23%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 98.36%	test accuracy: 94.87%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 98.51%	test accuracy: 94.72%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 98.65%	test accuracy: 94.49%
# -
# train epoch: 6
# Finished Training

# %%
# train all by each tensor(init with last weight) / new_score
clip_model, preprocess = clip.load("ViT-B/32", device=device)
model = OurCLIP(clip_model, 
                use_one_projection1=False, use_one_projection2=False,
                trainable_projection1=True, trainable_projection2=True,
                score_type=3).to(device)

# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print(name, param.shape)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.1)

start_train(model, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='train all by each tensor(init with last weight) / new_score',
            print_log=False)

torch.save(model.state_dict(), 'saved/allNewModel.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 58.84%	test accuracy: 43.89%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 73.93%	test accuracy: 46.34%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 79.88%	test accuracy: 45.86%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 83.76%	test accuracy: 48.31%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 86.60%	test accuracy: 50.30%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 88.39%	test accuracy: 51.17%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 89.66%	test accuracy: 53.47%
# ------------------ Training Epoch 8 ------------------
# train accuracy: 90.46%	test accuracy: 58.91%
# ------------------ Training Epoch 9 ------------------
# train accuracy: 91.33%	test accuracy: 64.95%
# ------------------ Training Epoch 10 ------------------
# train accuracy: 91.89%	test accuracy: 69.98%
# ------------------ Training Epoch 11 ------------------
# train accuracy: 92.45%	test accuracy: 74.90%
# ------------------ Training Epoch 12 ------------------
# train accuracy: 92.83%	test accuracy: 77.37%
# ------------------ Training Epoch 13 ------------------
# train accuracy: 93.24%	test accuracy: 80.14%
# ------------------ Training Epoch 14 ------------------
# train accuracy: 93.64%	test accuracy: 81.96%
# ------------------ Training Epoch 15 ------------------
# train accuracy: 93.87%	test accuracy: 83.68%
# ------------------ Training Epoch 16 ------------------
# train accuracy: 94.16%	test accuracy: 84.55%
# ------------------ Training Epoch 17 ------------------
# train accuracy: 94.32%	test accuracy: 85.18%
# ------------------ Training Epoch 18 ------------------
# train accuracy: 94.43%	test accuracy: 85.59%
# ------------------ Training Epoch 19 ------------------
# train accuracy: 94.61%	test accuracy: 85.79%
# ------------------ Training Epoch 20 ------------------
# train accuracy: 94.70%	test accuracy: 85.98%
# ------------------ Training Epoch 21 ------------------
# train accuracy: 94.79%	test accuracy: 86.16%
# ------------------ Training Epoch 22 ------------------
# train accuracy: 94.95%	test accuracy: 86.38%
# ------------------ Training Epoch 23 ------------------
# train accuracy: 95.07%	test accuracy: 86.24%
# ------------------ Training Epoch 24 ------------------
# train accuracy: 95.08%	test accuracy: 86.38%
# ------------------ Training Epoch 25 ------------------
# train accuracy: 95.20%	test accuracy: 86.59%
# ------------------ Training Epoch 26 ------------------
# train accuracy: 95.32%	test accuracy: 86.63%
# ------------------ Training Epoch 27 ------------------
# train accuracy: 95.38%	test accuracy: 86.67%
# ------------------ Training Epoch 28 ------------------
# train accuracy: 95.46%	test accuracy: 86.84%
# ------------------ Training Epoch 29 ------------------
# train accuracy: 95.54%	test accuracy: 86.90%
# ------------------ Training Epoch 30 ------------------
# train accuracy: 95.59%	test accuracy: 87.10%
# ------------------ Training Epoch 31 ------------------
# train accuracy: 95.66%	test accuracy: 87.16%
# ------------------ Training Epoch 32 ------------------
# train accuracy: 95.71%	test accuracy: 87.04%
# ------------------ Training Epoch 33 ------------------
# train accuracy: 95.82%	test accuracy: 87.16%
# ------------------ Training Epoch 34 ------------------
# train accuracy: 95.83%	test accuracy: 87.21%
# ------------------ Training Epoch 35 ------------------
# train accuracy: 95.91%	test accuracy: 87.42%
# ------------------ Training Epoch 36 ------------------
# train accuracy: 95.95%	test accuracy: 87.43%
# ------------------ Training Epoch 37 ------------------
# train accuracy: 96.03%	test accuracy: 87.42%
# ------------------ Training Epoch 38 ------------------
# train accuracy: 96.07%	test accuracy: 87.55%
# ------------------ Training Epoch 39 ------------------
# train accuracy: 96.16%	test accuracy: 87.51%
# ------------------ Training Epoch 40 ------------------
# train accuracy: 96.20%	test accuracy: 87.71%
# ------------------ Training Epoch 41 ------------------
# train accuracy: 96.28%	test accuracy: 87.67%
# ------------------ Training Epoch 42 ------------------
# train accuracy: 96.29%	test accuracy: 87.76%
# ------------------ Training Epoch 43 ------------------
# train accuracy: 96.35%	test accuracy: 87.83%
# ------------------ Training Epoch 44 ------------------
# train accuracy: 96.40%	test accuracy: 87.98%
# ------------------ Training Epoch 45 ------------------
# train accuracy: 96.47%	test accuracy: 88.11%
# ------------------ Training Epoch 46 ------------------
# train accuracy: 96.51%	test accuracy: 88.17%
# ------------------ Training Epoch 47 ------------------
# train accuracy: 96.54%	test accuracy: 88.09%
# ------------------ Training Epoch 48 ------------------
# train accuracy: 96.58%	test accuracy: 88.20%
# ------------------ Training Epoch 49 ------------------
# train accuracy: 96.66%	test accuracy: 88.27%
# ------------------ Training Epoch 50 ------------------
# train accuracy: 96.66%	test accuracy: 88.41%
# ------------------ Training Epoch 51 ------------------
# train accuracy: 96.74%	test accuracy: 88.47%
# ------------------ Training Epoch 52 ------------------
# train accuracy: 96.76%	test accuracy: 88.51%
# ------------------ Training Epoch 53 ------------------
# train accuracy: 96.79%	test accuracy: 88.64%
# ------------------ Training Epoch 54 ------------------
# train accuracy: 96.85%	test accuracy: 88.70%
# ------------------ Training Epoch 55 ------------------
# train accuracy: 96.86%	test accuracy: 88.92%
# ------------------ Training Epoch 56 ------------------
# train accuracy: 96.90%	test accuracy: 88.70%
# ------------------ Training Epoch 57 ------------------
# train accuracy: 96.91%	test accuracy: 88.93%
# ------------------ Training Epoch 58 ------------------
# train accuracy: 96.96%	test accuracy: 88.93%
# ------------------ Training Epoch 59 ------------------
# train accuracy: 96.98%	test accuracy: 89.10%
# ------------------ Training Epoch 60 ------------------
# train accuracy: 96.97%	test accuracy: 89.05%
# ------------------ Training Epoch 61 ------------------
# train accuracy: 97.01%	test accuracy: 89.22%
# ------------------ Training Epoch 62 ------------------
# train accuracy: 97.00%	test accuracy: 89.24%
# ------------------ Training Epoch 63 ------------------
# train accuracy: 97.01%	test accuracy: 89.44%
# ------------------ Training Epoch 64 ------------------
# train accuracy: 97.03%	test accuracy: 89.39%
# ------------------ Training Epoch 65 ------------------
# train accuracy: 97.06%	test accuracy: 89.51%
# ------------------ Training Epoch 66 ------------------
# train accuracy: 97.04%	test accuracy: 89.61%
# ------------------ Training Epoch 67 ------------------
# train accuracy: 97.05%	test accuracy: 89.71%
# ------------------ Training Epoch 68 ------------------
# train accuracy: 97.06%	test accuracy: 89.76%
# ------------------ Training Epoch 69 ------------------
# train accuracy: 97.08%	test accuracy: 89.71%
# ------------------ Training Epoch 70 ------------------
# train accuracy: 97.11%	test accuracy: 89.79%
# ------------------ Training Epoch 71 ------------------
# train accuracy: 97.13%	test accuracy: 89.90%
# ------------------ Training Epoch 72 ------------------
# train accuracy: 97.13%	test accuracy: 89.81%
# ------------------ Training Epoch 73 ------------------
# train accuracy: 97.13%	test accuracy: 89.88%
# ------------------ Training Epoch 74 ------------------
# train accuracy: 97.13%	test accuracy: 89.79%
# ------------------ Training Epoch 75 ------------------
# train accuracy: 97.11%	test accuracy: 90.13%
# ------------------ Training Epoch 76 ------------------
# train accuracy: 97.16%	test accuracy: 89.96%
# ------------------ Training Epoch 77 ------------------
# train accuracy: 97.16%	test accuracy: 90.10%
# ------------------ Training Epoch 78 ------------------
# train accuracy: 97.16%	test accuracy: 90.08%
# ------------------ Training Epoch 79 ------------------
# train accuracy: 97.17%	test accuracy: 90.04%
# ------------------ Training Epoch 80 ------------------
# train accuracy: 97.14%	test accuracy: 90.05%
# -
# train epoch: 79
# Finished Training

# %%
# train all by each tensor(init with randn weight) / max_score
clip_model, preprocess = clip.load("ViT-B/32", device=device)
model = OurCLIP(clip_model, 
                use_one_projection1=False, use_one_projection2=False,
                trainable_projection1=True, trainable_projection2=True,
                projection_random_init1=True,
                projection_random_init2=True,
                score_type=0).to(device)

# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print(name, param.shape)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.1)

start_train(model, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='train all by each tensor(init with randn weight) / max_score',
            print_log=False)

torch.save(model.state_dict(), 'saved/allMaxRandInitModel.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 96.52%	test accuracy: 95.75%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 97.68%	test accuracy: 95.80%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 98.03%	test accuracy: 95.53%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 98.28%	test accuracy: 95.25%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 98.37%	test accuracy: 94.91%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 98.52%	test accuracy: 94.77%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 98.65%	test accuracy: 94.52%
# -
# train epoch: 6
# Finished Training

# %%
# train all by each tensor(init with randn weight) / new_score
clip_model, preprocess = clip.load("ViT-B/32", device=device)
model = OurCLIP(clip_model, 
                use_one_projection1=False, use_one_projection2=False,
                trainable_projection1=True, trainable_projection2=True,
                projection_random_init1=True,
                projection_random_init2=True,
                score_type=3).to(device)

# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print(name, param.shape)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.1)

start_train(model, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='train all by each tensor(init with randn weight) / new_score',
            print_log=False)

torch.save(model.state_dict(), 'saved/allNewRandInitModel.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 84.14%	test accuracy: 64.72%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 90.91%	test accuracy: 85.47%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 93.71%	test accuracy: 90.05%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 94.90%	test accuracy: 90.95%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 95.64%	test accuracy: 91.22%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 96.13%	test accuracy: 91.07%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 96.22%	test accuracy: 90.34%
# ------------------ Training Epoch 8 ------------------
# train accuracy: 96.26%	test accuracy: 90.22%
# ------------------ Training Epoch 9 ------------------
# train accuracy: 96.46%	test accuracy: 91.08%
# ------------------ Training Epoch 10 ------------------
# train accuracy: 96.58%	test accuracy: 90.99%
# -
# train epoch: 9
# Finished Training

# %% [markdown]
# # LR -> 0.00001

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)

oneMaxModel = OurCLIP(clip_model, trainable_projection1=True, trainable_projection2=True, score_type=0).to(device)
oneMaxModel.load_state_dict(torch.load('saved/oneMaxModel.pt'))
oneNewModel = OurCLIP(clip_model, trainable_projection1=True, trainable_projection2=True, score_type=3).to(device)
oneNewModel.load_state_dict(torch.load('saved/oneNewModel.pt'))
allMaxModel = OurCLIP(clip_model, 
                use_one_projection1=False, use_one_projection2=False,
                trainable_projection1=True, trainable_projection2=True,
                score_type=0).to(device)
allMaxModel.load_state_dict(torch.load('saved/allMaxModel.pt'))
allNewModel = OurCLIP(clip_model, 
                use_one_projection1=False, use_one_projection2=False,
                trainable_projection1=True, trainable_projection2=True,
                score_type=3).to(device)
allNewModel.load_state_dict(torch.load('saved/allNewModel.pt'))
allMaxRandInitModel = OurCLIP(clip_model, 
                use_one_projection1=False, use_one_projection2=False,
                trainable_projection1=True, trainable_projection2=True,
                projection_random_init1=True,
                projection_random_init2=True,
                score_type=0).to(device)
allMaxRandInitModel.load_state_dict(torch.load('saved/allMaxRandInitModel.pt'))
allNewRandInitModel = OurCLIP(clip_model, 
                use_one_projection1=False, use_one_projection2=False,
                trainable_projection1=True, trainable_projection2=True,
                projection_random_init1=True,
                projection_random_init2=True,
                score_type=3).to(device)
allNewRandInitModel.load_state_dict(torch.load('saved/allNewRandInitModel.pt'))
# Out:
# <All keys matched successfully>

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(oneMaxModel.parameters(), lr=0.00001, momentum=0.1)

start_train(oneMaxModel, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='oneMaxModel / lr=0.00001',
            print_log=False)

torch.save(model.state_dict(), 'saved/oneMaxModelFT.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 95.57%	test accuracy: 96.13%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 96.45%	test accuracy: 96.54%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 96.68%	test accuracy: 96.68%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 96.89%	test accuracy: 96.76%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 97.00%	test accuracy: 96.85%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 96.99%	test accuracy: 96.85%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 97.03%	test accuracy: 96.85%
# ------------------ Training Epoch 8 ------------------
# train accuracy: 97.04%	test accuracy: 96.86%
# ------------------ Training Epoch 9 ------------------
# train accuracy: 97.06%	test accuracy: 96.84%
# ------------------ Training Epoch 10 ------------------
# train accuracy: 97.07%	test accuracy: 96.83%
# ------------------ Training Epoch 11 ------------------
# train accuracy: 97.04%	test accuracy: 96.86%
# ------------------ Training Epoch 12 ------------------
# train accuracy: 97.05%	test accuracy: 96.84%
# ------------------ Training Epoch 13 ------------------
# train accuracy: 97.05%	test accuracy: 96.85%
# -
# train epoch: 12
# Finished Training

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(oneNewModel.parameters(), lr=0.00001, momentum=0.1)

start_train(oneNewModel, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='oneNewModel / lr=0.00001',
            print_log=False)

torch.save(model.state_dict(), 'saved/oneNewModelFT.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 92.56%	test accuracy: 93.39%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 93.86%	test accuracy: 94.34%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 94.43%	test accuracy: 94.56%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 94.59%	test accuracy: 94.67%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 94.60%	test accuracy: 94.72%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 94.68%	test accuracy: 94.73%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 94.76%	test accuracy: 94.78%
# ------------------ Training Epoch 8 ------------------
# train accuracy: 94.79%	test accuracy: 94.85%
# ------------------ Training Epoch 9 ------------------
# train accuracy: 94.81%	test accuracy: 94.84%
# ------------------ Training Epoch 10 ------------------
# train accuracy: 94.86%	test accuracy: 94.85%
# ------------------ Training Epoch 11 ------------------
# train accuracy: 94.91%	test accuracy: 94.87%
# ------------------ Training Epoch 12 ------------------
# train accuracy: 94.88%	test accuracy: 94.88%
# ------------------ Training Epoch 13 ------------------
# train accuracy: 94.90%	test accuracy: 94.90%
# ------------------ Training Epoch 14 ------------------
# train accuracy: 94.91%	test accuracy: 94.88%
# ------------------ Training Epoch 15 ------------------
# train accuracy: 94.93%	test accuracy: 94.88%
# ------------------ Training Epoch 16 ------------------
# train accuracy: 94.91%	test accuracy: 94.91%
# ------------------ Training Epoch 17 ------------------
# train accuracy: 94.93%	test accuracy: 94.90%
# ------------------ Training Epoch 18 ------------------
# train accuracy: 94.95%	test accuracy: 94.91%
# ------------------ Training Epoch 19 ------------------
# train accuracy: 94.93%	test accuracy: 94.92%
# ------------------ Training Epoch 20 ------------------
# train accuracy: 94.93%	test accuracy: 94.90%
# ------------------ Training Epoch 21 ------------------
# train accuracy: 94.96%	test accuracy: 94.93%
# ------------------ Training Epoch 22 ------------------
# train accuracy: 94.98%	test accuracy: 94.93%
# ------------------ Training Epoch 23 ------------------
# train accuracy: 94.95%	test accuracy: 94.96%
# ------------------ Training Epoch 24 ------------------
# train accuracy: 94.98%	test accuracy: 94.93%
# ------------------ Training Epoch 25 ------------------
# train accuracy: 94.99%	test accuracy: 94.96%
# ------------------ Training Epoch 26 ------------------
# train accuracy: 94.98%	test accuracy: 94.96%
# ------------------ Training Epoch 27 ------------------
# train accuracy: 94.98%	test accuracy: 94.96%
# ------------------ Training Epoch 28 ------------------
# train accuracy: 94.99%	test accuracy: 94.97%
# ------------------ Training Epoch 29 ------------------
# train accuracy: 94.98%	test accuracy: 94.94%
# ------------------ Training Epoch 30 ------------------
# train accuracy: 94.96%	test accuracy: 94.97%
# ------------------ Training Epoch 31 ------------------
# train accuracy: 94.99%	test accuracy: 94.98%
# ------------------ Training Epoch 32 ------------------
# train accuracy: 94.99%	test accuracy: 95.00%
# ------------------ Training Epoch 33 ------------------
# train accuracy: 94.99%	test accuracy: 94.97%
# ------------------ Training Epoch 34 ------------------
# train accuracy: 94.99%	test accuracy: 94.99%
# ------------------ Training Epoch 35 ------------------
# train accuracy: 94.98%	test accuracy: 95.00%
# ------------------ Training Epoch 36 ------------------
# train accuracy: 94.99%	test accuracy: 95.00%
# ------------------ Training Epoch 37 ------------------
# train accuracy: 95.01%	test accuracy: 95.01%
# ------------------ Training Epoch 38 ------------------
# train accuracy: 95.02%	test accuracy: 95.01%
# ------------------ Training Epoch 39 ------------------
# train accuracy: 95.02%	test accuracy: 94.99%
# ------------------ Training Epoch 40 ------------------
# train accuracy: 95.04%	test accuracy: 95.00%
# ------------------ Training Epoch 41 ------------------
# train accuracy: 95.03%	test accuracy: 95.02%
# ------------------ Training Epoch 42 ------------------
# train accuracy: 95.03%	test accuracy: 95.02%
# ------------------ Training Epoch 43 ------------------
# train accuracy: 95.04%	test accuracy: 95.02%
# ------------------ Training Epoch 44 ------------------
# train accuracy: 95.05%	test accuracy: 95.02%
# ------------------ Training Epoch 45 ------------------
# train accuracy: 95.05%	test accuracy: 95.03%
# ------------------ Training Epoch 46 ------------------
# train accuracy: 95.07%	test accuracy: 95.03%
# ------------------ Training Epoch 47 ------------------
# train accuracy: 95.05%	test accuracy: 95.02%
# ------------------ Training Epoch 48 ------------------
# train accuracy: 95.07%	test accuracy: 95.02%
# ------------------ Training Epoch 49 ------------------
# train accuracy: 95.08%	test accuracy: 95.06%
# ------------------ Training Epoch 50 ------------------
# train accuracy: 95.08%	test accuracy: 95.06%
# ------------------ Training Epoch 51 ------------------
# train accuracy: 95.08%	test accuracy: 95.06%
# ------------------ Training Epoch 52 ------------------
# train accuracy: 95.08%	test accuracy: 95.05%
# ------------------ Training Epoch 53 ------------------
# train accuracy: 95.08%	test accuracy: 95.05%
# ------------------ Training Epoch 54 ------------------
# train accuracy: 95.09%	test accuracy: 95.06%
# -
# train epoch: 53
# Finished Training

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(allMaxModel.parameters(), lr=0.00001, momentum=0.1)

start_train(allMaxModel, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='allMaxModel / lr=0.00001',
            print_log=False)

torch.save(model.state_dict(), 'saved/allMaxModelFT.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 95.52%	test accuracy: 96.16%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 96.49%	test accuracy: 96.62%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 96.70%	test accuracy: 96.75%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 96.94%	test accuracy: 96.86%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 97.01%	test accuracy: 96.92%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 97.00%	test accuracy: 96.91%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 97.06%	test accuracy: 96.92%
# ------------------ Training Epoch 8 ------------------
# train accuracy: 97.06%	test accuracy: 96.91%
# ------------------ Training Epoch 9 ------------------
# train accuracy: 97.08%	test accuracy: 96.94%
# ------------------ Training Epoch 10 ------------------
# train accuracy: 97.11%	test accuracy: 96.95%
# ------------------ Training Epoch 11 ------------------
# train accuracy: 97.14%	test accuracy: 96.94%
# ------------------ Training Epoch 12 ------------------
# train accuracy: 97.13%	test accuracy: 96.98%
# ------------------ Training Epoch 13 ------------------
# train accuracy: 97.14%	test accuracy: 96.98%
# ------------------ Training Epoch 14 ------------------
# train accuracy: 97.16%	test accuracy: 96.99%
# ------------------ Training Epoch 15 ------------------
# train accuracy: 97.16%	test accuracy: 96.97%
# ------------------ Training Epoch 16 ------------------
# train accuracy: 97.16%	test accuracy: 96.98%
# ------------------ Training Epoch 17 ------------------
# train accuracy: 97.15%	test accuracy: 96.99%
# ------------------ Training Epoch 18 ------------------
# train accuracy: 97.17%	test accuracy: 96.99%
# ------------------ Training Epoch 19 ------------------
# train accuracy: 97.15%	test accuracy: 97.00%
# ------------------ Training Epoch 20 ------------------
# train accuracy: 97.16%	test accuracy: 97.00%
# ------------------ Training Epoch 21 ------------------
# train accuracy: 97.14%	test accuracy: 97.02%
# ------------------ Training Epoch 22 ------------------
# train accuracy: 97.16%	test accuracy: 96.98%
# ------------------ Training Epoch 23 ------------------
# train accuracy: 97.14%	test accuracy: 97.00%
# ------------------ Training Epoch 24 ------------------
# train accuracy: 97.15%	test accuracy: 96.99%
# ------------------ Training Epoch 25 ------------------
# train accuracy: 97.14%	test accuracy: 96.98%
# ------------------ Training Epoch 26 ------------------
# train accuracy: 97.13%	test accuracy: 96.98%
# -
# train epoch: 25
# Finished Training

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(allNewModel.parameters(), lr=0.00001, momentum=0.1)

start_train(allNewModel, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='allNewModel / lr=0.00001',
            print_log=False)

torch.save(model.state_dict(), 'saved/allNewModelFT.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 91.10%	test accuracy: 91.92%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 92.69%	test accuracy: 93.19%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 93.58%	test accuracy: 93.72%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 94.00%	test accuracy: 94.10%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 94.27%	test accuracy: 94.41%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 94.54%	test accuracy: 94.59%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 94.71%	test accuracy: 94.80%
# ------------------ Training Epoch 8 ------------------
# train accuracy: 94.75%	test accuracy: 94.85%
# ------------------ Training Epoch 9 ------------------
# train accuracy: 94.85%	test accuracy: 94.87%
# ------------------ Training Epoch 10 ------------------
# train accuracy: 94.85%	test accuracy: 94.94%
# ------------------ Training Epoch 11 ------------------
# train accuracy: 94.92%	test accuracy: 95.02%
# ------------------ Training Epoch 12 ------------------
# train accuracy: 95.00%	test accuracy: 95.09%
# ------------------ Training Epoch 13 ------------------
# train accuracy: 95.05%	test accuracy: 95.10%
# ------------------ Training Epoch 14 ------------------
# train accuracy: 95.03%	test accuracy: 95.12%
# ------------------ Training Epoch 15 ------------------
# train accuracy: 95.03%	test accuracy: 95.13%
# ------------------ Training Epoch 16 ------------------
# train accuracy: 95.04%	test accuracy: 95.14%
# ------------------ Training Epoch 17 ------------------
# train accuracy: 95.07%	test accuracy: 95.12%
# ------------------ Training Epoch 18 ------------------
# train accuracy: 95.10%	test accuracy: 95.13%
# ------------------ Training Epoch 19 ------------------
# train accuracy: 95.15%	test accuracy: 95.14%
# ------------------ Training Epoch 20 ------------------
# train accuracy: 95.14%	test accuracy: 95.18%
# ------------------ Training Epoch 21 ------------------
# train accuracy: 95.13%	test accuracy: 95.15%
# ------------------ Training Epoch 22 ------------------
# train accuracy: 95.14%	test accuracy: 95.17%
# ------------------ Training Epoch 23 ------------------
# train accuracy: 95.18%	test accuracy: 95.13%
# ------------------ Training Epoch 24 ------------------
# train accuracy: 95.15%	test accuracy: 95.12%
# ------------------ Training Epoch 25 ------------------
# train accuracy: 95.14%	test accuracy: 95.20%
# ------------------ Training Epoch 26 ------------------
# train accuracy: 95.17%	test accuracy: 95.21%
# ------------------ Training Epoch 27 ------------------
# train accuracy: 95.21%	test accuracy: 95.22%
# ------------------ Training Epoch 28 ------------------
# train accuracy: 95.20%	test accuracy: 95.21%
# ------------------ Training Epoch 29 ------------------
# train accuracy: 95.18%	test accuracy: 95.21%
# ------------------ Training Epoch 30 ------------------
# train accuracy: 95.18%	test accuracy: 95.22%
# ------------------ Training Epoch 31 ------------------
# train accuracy: 95.19%	test accuracy: 95.21%
# ------------------ Training Epoch 32 ------------------
# train accuracy: 95.19%	test accuracy: 95.21%
# -
# train epoch: 31
# Finished Training

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(allMaxRandInitModel.parameters(), lr=0.00001, momentum=0.1)

start_train(allMaxRandInitModel, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='allMaxRandInitModel / lr=0.00001',
            print_log=False)

torch.save(model.state_dict(), 'saved/allMaxRandInitModelFT.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 95.50%	test accuracy: 96.17%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 96.50%	test accuracy: 96.61%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 96.71%	test accuracy: 96.78%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 96.94%	test accuracy: 96.86%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 97.03%	test accuracy: 96.93%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 97.04%	test accuracy: 96.94%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 97.04%	test accuracy: 96.98%
# ------------------ Training Epoch 8 ------------------
# train accuracy: 97.09%	test accuracy: 96.97%
# ------------------ Training Epoch 9 ------------------
# train accuracy: 97.09%	test accuracy: 96.96%
# ------------------ Training Epoch 10 ------------------
# train accuracy: 97.11%	test accuracy: 96.98%
# ------------------ Training Epoch 11 ------------------
# train accuracy: 97.10%	test accuracy: 96.97%
# ------------------ Training Epoch 12 ------------------
# train accuracy: 97.14%	test accuracy: 96.97%
# -
# train epoch: 11
# Finished Training

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(allNewRandInitModel.parameters(), lr=0.00001, momentum=0.1)

start_train(allNewRandInitModel, criterion, optimizer, num_epochs=num_epochs, patience=patience,
            save_path='output0316.txt', save_content='allNewRandInitModel / lr=0.00001',
            print_log=False)

torch.save(model.state_dict(), 'saved/allNewRandInitModelFT.pt')
# Out:
# ------------------ Training Epoch 1 ------------------
# train accuracy: 91.08%	test accuracy: 91.29%
# ------------------ Training Epoch 2 ------------------
# train accuracy: 91.30%	test accuracy: 91.44%
# ------------------ Training Epoch 3 ------------------
# train accuracy: 91.48%	test accuracy: 91.66%
# ------------------ Training Epoch 4 ------------------
# train accuracy: 91.63%	test accuracy: 91.82%
# ------------------ Training Epoch 5 ------------------
# train accuracy: 91.80%	test accuracy: 91.94%
# ------------------ Training Epoch 6 ------------------
# train accuracy: 91.95%	test accuracy: 92.11%
# ------------------ Training Epoch 7 ------------------
# train accuracy: 92.05%	test accuracy: 92.21%
# ------------------ Training Epoch 8 ------------------
# train accuracy: 92.17%	test accuracy: 92.31%
# ------------------ Training Epoch 9 ------------------
# train accuracy: 92.21%	test accuracy: 92.42%
# ------------------ Training Epoch 10 ------------------
# train accuracy: 92.36%	test accuracy: 92.51%
# ------------------ Training Epoch 11 ------------------
# train accuracy: 92.44%	test accuracy: 92.59%
# ------------------ Training Epoch 12 ------------------
# train accuracy: 92.51%	test accuracy: 92.71%
# ------------------ Training Epoch 13 ------------------
# train accuracy: 92.68%	test accuracy: 92.75%
# ------------------ Training Epoch 14 ------------------
# train accuracy: 92.69%	test accuracy: 92.82%
# ------------------ Training Epoch 15 ------------------
# train accuracy: 92.77%	test accuracy: 92.86%
# ------------------ Training Epoch 16 ------------------
# train accuracy: 92.83%	test accuracy: 92.92%
# ------------------ Training Epoch 17 ------------------
# train accuracy: 92.87%	test accuracy: 92.95%
# ------------------ Training Epoch 18 ------------------
# train accuracy: 92.92%	test accuracy: 93.00%
# ------------------ Training Epoch 19 ------------------
# train accuracy: 92.95%	test accuracy: 93.05%
# ------------------ Training Epoch 20 ------------------
# train accuracy: 93.03%	test accuracy: 93.11%
# ------------------ Training Epoch 21 ------------------
# train accuracy: 93.07%	test accuracy: 93.20%
# ------------------ Training Epoch 22 ------------------
# train accuracy: 93.15%	test accuracy: 93.25%
# ------------------ Training Epoch 23 ------------------
# train accuracy: 93.17%	test accuracy: 93.32%
# ------------------ Training Epoch 24 ------------------
# train accuracy: 93.26%	test accuracy: 93.37%
# ------------------ Training Epoch 25 ------------------
# train accuracy: 93.25%	test accuracy: 93.38%
# ------------------ Training Epoch 26 ------------------
# train accuracy: 93.31%	test accuracy: 93.40%
# ------------------ Training Epoch 27 ------------------
# train accuracy: 93.32%	test accuracy: 93.43%
# ------------------ Training Epoch 28 ------------------
# train accuracy: 93.35%	test accuracy: 93.48%
# ------------------ Training Epoch 29 ------------------
# train accuracy: 93.39%	test accuracy: 93.48%
# ------------------ Training Epoch 30 ------------------
# train accuracy: 93.39%	test accuracy: 93.52%
# ------------------ Training Epoch 31 ------------------
# train accuracy: 93.42%	test accuracy: 93.52%
# ------------------ Training Epoch 32 ------------------
# train accuracy: 93.45%	test accuracy: 93.58%
# ------------------ Training Epoch 33 ------------------
# train accuracy: 93.48%	test accuracy: 93.60%
# ------------------ Training Epoch 34 ------------------
# train accuracy: 93.52%	test accuracy: 93.63%
# ------------------ Training Epoch 35 ------------------
# train accuracy: 93.53%	test accuracy: 93.65%
# ------------------ Training Epoch 36 ------------------
# train accuracy: 93.57%	test accuracy: 93.66%
# ------------------ Training Epoch 37 ------------------
# train accuracy: 93.57%	test accuracy: 93.65%
# ------------------ Training Epoch 38 ------------------
# train accuracy: 93.59%	test accuracy: 93.66%
# ------------------ Training Epoch 39 ------------------
# train accuracy: 93.58%	test accuracy: 93.72%
# ------------------ Training Epoch 40 ------------------
# train accuracy: 93.62%	test accuracy: 93.74%
# ------------------ Training Epoch 41 ------------------
# train accuracy: 93.64%	test accuracy: 93.76%
# ------------------ Training Epoch 42 ------------------
# train accuracy: 93.69%	test accuracy: 93.77%
# ------------------ Training Epoch 43 ------------------
# train accuracy: 93.68%	test accuracy: 93.77%
# ------------------ Training Epoch 44 ------------------
# train accuracy: 93.76%	test accuracy: 93.82%
# ------------------ Training Epoch 45 ------------------
# train accuracy: 93.75%	test accuracy: 93.83%
# ------------------ Training Epoch 46 ------------------
# train accuracy: 93.76%	test accuracy: 93.84%
# ------------------ Training Epoch 47 ------------------
# train accuracy: 93.76%	test accuracy: 93.82%
# ------------------ Training Epoch 48 ------------------
# train accuracy: 93.76%	test accuracy: 93.81%
# ------------------ Training Epoch 49 ------------------
# train accuracy: 93.80%	test accuracy: 93.86%
# ------------------ Training Epoch 50 ------------------
# train accuracy: 93.80%	test accuracy: 93.87%
# ------------------ Training Epoch 51 ------------------
# train accuracy: 93.82%	test accuracy: 93.90%
# ------------------ Training Epoch 52 ------------------
# train accuracy: 93.82%	test accuracy: 93.91%
# ------------------ Training Epoch 53 ------------------
# train accuracy: 93.81%	test accuracy: 93.89%
# ------------------ Training Epoch 54 ------------------
# train accuracy: 93.83%	test accuracy: 93.90%
# ------------------ Training Epoch 55 ------------------
# train accuracy: 93.84%	test accuracy: 93.91%
# ------------------ Training Epoch 56 ------------------
# train accuracy: 93.85%	test accuracy: 93.91%
# ------------------ Training Epoch 57 ------------------
# train accuracy: 93.85%	test accuracy: 93.94%
# ------------------ Training Epoch 58 ------------------
# train accuracy: 93.84%	test accuracy: 93.93%
# ------------------ Training Epoch 59 ------------------
# train accuracy: 93.88%	test accuracy: 93.94%
# ------------------ Training Epoch 60 ------------------
# train accuracy: 93.90%	test accuracy: 93.97%
# ------------------ Training Epoch 61 ------------------
# train accuracy: 93.94%	test accuracy: 93.99%
# ------------------ Training Epoch 62 ------------------
# train accuracy: 93.92%	test accuracy: 94.00%
# ------------------ Training Epoch 63 ------------------
# train accuracy: 93.95%	test accuracy: 94.01%
# ------------------ Training Epoch 64 ------------------
# train accuracy: 93.93%	test accuracy: 93.99%
# ------------------ Training Epoch 65 ------------------
# train accuracy: 93.96%	test accuracy: 94.03%
# ------------------ Training Epoch 66 ------------------
# train accuracy: 93.98%	test accuracy: 94.05%
# ------------------ Training Epoch 67 ------------------
# train accuracy: 93.96%	test accuracy: 94.05%
# ------------------ Training Epoch 68 ------------------
# train accuracy: 93.98%	test accuracy: 94.05%
# ------------------ Training Epoch 69 ------------------
# train accuracy: 93.97%	test accuracy: 94.06%
# ------------------ Training Epoch 70 ------------------
# train accuracy: 94.00%	test accuracy: 94.07%
# ------------------ Training Epoch 71 ------------------
# train accuracy: 94.01%	test accuracy: 94.07%
# ------------------ Training Epoch 72 ------------------
# train accuracy: 94.02%	test accuracy: 94.07%
# ------------------ Training Epoch 73 ------------------
# train accuracy: 94.03%	test accuracy: 94.08%
# ------------------ Training Epoch 74 ------------------
# train accuracy: 94.04%	test accuracy: 94.07%
# ------------------ Training Epoch 75 ------------------
# train accuracy: 94.02%	test accuracy: 94.09%
# ------------------ Training Epoch 76 ------------------
# train accuracy: 94.03%	test accuracy: 94.11%
# ------------------ Training Epoch 77 ------------------
# train accuracy: 94.03%	test accuracy: 94.10%
# ------------------ Training Epoch 78 ------------------
# train accuracy: 94.04%	test accuracy: 94.09%
# ------------------ Training Epoch 79 ------------------
# train accuracy: 94.03%	test accuracy: 94.12%
# ------------------ Training Epoch 80 ------------------
# train accuracy: 94.06%	test accuracy: 94.13%
# ------------------ Training Epoch 81 ------------------
# train accuracy: 94.06%	test accuracy: 94.12%
# ------------------ Training Epoch 82 ------------------
# train accuracy: 94.07%	test accuracy: 94.13%
# ------------------ Training Epoch 83 ------------------
# train accuracy: 94.06%	test accuracy: 94.14%
# ------------------ Training Epoch 84 ------------------
# train accuracy: 94.07%	test accuracy: 94.14%
# ------------------ Training Epoch 85 ------------------
# train accuracy: 94.10%	test accuracy: 94.15%
# ------------------ Training Epoch 86 ------------------
# train accuracy: 94.07%	test accuracy: 94.12%
# ------------------ Training Epoch 87 ------------------
# train accuracy: 94.07%	test accuracy: 94.17%
# ------------------ Training Epoch 88 ------------------
# train accuracy: 94.14%	test accuracy: 94.17%
# ------------------ Training Epoch 89 ------------------
# train accuracy: 94.11%	test accuracy: 94.16%
# ------------------ Training Epoch 90 ------------------
# train accuracy: 94.14%	test accuracy: 94.15%
# ------------------ Training Epoch 91 ------------------
# train accuracy: 94.14%	test accuracy: 94.16%
# ------------------ Training Epoch 92 ------------------
# train accuracy: 94.13%	test accuracy: 94.16%
# -
# train epoch: 91
# Finished Training

# %% [markdown]
# # zeroshot clip

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)

# %%
with open('train_labels_list0.pickle', 'rb') as fr:
    train_labels_list0 = pickle.load(fr)
with open('train_images_feature_list.pickle', 'rb') as fr:
    train_images_feature_list = pickle.load(fr)
with open('test_labels_list0.pickle', 'rb') as fr:
    test_labels_list0 = pickle.load(fr)
with open('test_images_feature_list.pickle', 'rb') as fr:
    test_images_feature_list = pickle.load(fr)
with open('class_features0.pickle', 'rb') as fr:
    class_features0 = pickle.load(fr)

# %%
class _CLIP(nn.Module):        
    def __init__(self, clip_model): 
        super().__init__()

        self.dtype = clip_model.dtype
        self.visual_projection = nn.Parameter(clip_model.visual.proj.clone().detach()).requires_grad_(True)
        self.textual_projection = nn.Parameter(clip_model.text_projection.clone().detach()).requires_grad_(True)
        ####################### 학습할지 여부 결정하지 않았음
        self.ln_post = clip_model.visual.ln_post.requires_grad_(False)
        self.ln_final = clip_model.ln_final.requires_grad_(False)
        ########################
        self.logit_scale = clip_model.logit_scale

    def forward(self, image_features, class_features, class_tokens):
        image_features = self.ln_post(image_features)                       # (batch_size, 768)
        image_features = image_features @ self.visual_projection            # (batch_size, 512)  <- we'll use it

        class_features = self.ln_final(class_features).type(self.dtype)     # (seq_len, 77, 512)
        class_features = class_features[torch.arange(class_features.shape[0]), 
                                           class_tokens.argmax(dim=-1)] @ self.textual_projection
                                                                            # (seq_len, 512)  <- we'll use it

        # normalized features
        image_features = image_features / image_features.norm(dim=1, keepdim=True)
        class_features = class_features / class_features.norm(dim=1, keepdim=True)

        # cosine similarity as logits
        logit_scale = self.logit_scale.exp()
        logits_per_image = logit_scale * image_features @ class_features.t()
        logits_per_text = logits_per_image.t()

        # shape = [global_batch_size, global_batch_size]
        return logits_per_image, logits_per_text

# %%
# zeroshot
def test_model_for_clip_model(model, images_feature_list, labels_list, max_iter_num=1000):

    model.eval()

    total = 0
    correct = 0

    with torch.no_grad():
        for i in range(len(labels_list)):
            image_features = images_feature_list[i]
            labels = labels_list[i]

            # forward + backward + optimize
            outputs = model(image_features, class_features0, class_tokens)[0].softmax(dim=-1)
    
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            if i != 0 and i % max_iter_num == 0:
                break

        accuracy = 100 * correct / total
            
        print('Finished Testing')
        print('Testing accuracy: %.2f %%' %(accuracy))

    return accuracy

def train_model_for_clip_model(model, optimizer, criterion, images_feature_list, labels_list, max_iter_num=3000, print_log=True):

    model.train()

    running_loss = 0.0
    start_time = time.time()
    total = 0
    correct = 0
    
    for i in range(len(labels_list)):
        image_features = images_feature_list[i]
        labels = labels_list[i]

        # forward + backward + optimize
        outputs = model(image_features, class_features0, class_tokens)[0].softmax(dim=-1)
        
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        predicted = torch.argmax(outputs, dim=-1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
    
        # Print performance statistics
        running_loss += loss.item()

        if print_log:
            if i != 0 and i % 10 == 0:    # print every 10 batches
                batch_time = time.time()
                speed = (i+1)/(batch_time-start_time)
                print('[%5d] loss: %.3f, speed: %.2f, accuracy: %.2f %%' %
                    (i, running_loss, speed, accuracy))

                running_loss = 0.0
                total = 0
                correct = 0

        if i != 0 and i % max_iter_num == 0:
            break;
    
    return accuracy

# %%
model = _CLIP(clip_model)

accuracy = test_model_for_clip_model(model, test_images_feature_list, test_labels_list0)

with open("output0316.txt", 'a') as f:
    f.write("="*10+"clip / zeroshot\n")
    f.write(f"accuracy: {accuracy:.4f}\n")
# Out:
# Finished Testing
# Testing accuracy: 91.63 %

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)

model = _CLIP(clip_model)
model.logit_scale.requires_grad_(False)

for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.shape, param.requires_grad)
# Out:
# visual_projection torch.Size([768, 512]) True
# textual_projection torch.Size([512, 512]) True

# %%
patience = 5
num_epochs = 200

# %%
import time

model = _CLIP(clip_model)
model.logit_scale.requires_grad_(False)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.00001, momentum=0.1)   # lr이 .00001보다 작을 경우 학습이 망가짐

early_stop = EarlyStopping(patience)

for epoch in range(num_epochs):  # loop over the dataset multiple times
    print("------------------ Training Epoch {} ------------------".format(epoch+1))
    train_accuracy = train_model_for_clip_model(model, optimizer, criterion,
                                                train_images_feature_list, train_labels_list0, max_iter_num=1000, print_log=False)
    test_accuracy = test_model_for_clip_model(model, test_images_feature_list, test_labels_list0)
    print(f"train accuracy: {train_accuracy:.2f}%\ttest accuracy: {test_accuracy:.2f}%")

    early_stop.step(test_accuracy)

    if early_stop.is_stop():
        print(f"-\ntrain epoch: {epoch}")
        break

with open("output0316.txt", 'a') as f:
    f.write(f"{epoch+1}\t"+"="*10+f"clip linear probing\n")
    f.write(f"accuracy: {test_accuracy:.4f}\n")


print('Finished Training')
# Out:
# ------------------ Training Epoch 1 ------------------
# Finished Testing
# Testing accuracy: 58.69 %
# train accuracy: 85.26%	test accuracy: 58.69%
# ------------------ Training Epoch 2 ------------------
# Finished Testing
# Testing accuracy: 66.09 %
# train accuracy: 64.42%	test accuracy: 66.09%
# ------------------ Training Epoch 3 ------------------
# Finished Testing
# Testing accuracy: 84.30 %
# train accuracy: 73.89%	test accuracy: 84.30%
# ------------------ Training Epoch 4 ------------------
# Finished Testing
# Testing accuracy: 70.91 %
# train accuracy: 67.76%	test accuracy: 70.91%
# ------------------ Training Epoch 5 ------------------
# Finished Testing
# Testing accuracy: 79.30 %
# train accuracy: 74.27%	test accuracy: 79.30%
# ------------------ Training Epoch 6 ------------------
# Finished Testing
# Testing accuracy: 73.39 %
# train accuracy: 72.28%	test accuracy: 73.39%
# ------------------ Training Epoch 7 ------------------
# Finished Testing
# Testing accuracy: 86.71 %
# train accuracy: 80.58%	test accuracy: 86.71%
# ------------------ Training Epoch 8 ------------------
# Finished Testing
# Testing accuracy: 89.54 %
# train accuracy: 88.84%	test accuracy: 89.54%
# ------------------ Training Epoch 9 ------------------
# Finished Testing
# Testing accuracy: 87.62 %
# train accuracy: 88.07%	test accuracy: 87.62%
# ------------------ Training Epoch 10 ------------------
# Finished Testing
# Testing accuracy: 88.46 %
# train accuracy: 87.59%	test accuracy: 88.46%
# ------------------ Training Epoch 11 ------------------
# Finished Testing
# Testing accuracy: 90.56 %
# train accuracy: 89.84%	test accuracy: 90.56%
# ------------------ Training Epoch 12 ------------------
# Finished Testing
# Testing accuracy: 91.19 %
# train accuracy: 90.91%	test accuracy: 91.19%
# ------------------ Training Epoch 13 ------------------
# Finished Testing
# Testing accuracy: 91.74 %
# train accuracy: 91.31%	test accuracy: 91.74%
# ------------------ Training Epoch 14 ------------------
# Finished Testing
# Testing accuracy: 92.26 %
# train accuracy: 91.99%	test accuracy: 92.26%
# ------------------ Training Epoch 15 ------------------
# Finished Testing
# Testing accuracy: 92.42 %
# train accuracy: 92.46%	test accuracy: 92.42%
# ------------------ Training Epoch 16 ------------------
# Finished Testing
# Testing accuracy: 92.75 %
# train accuracy: 92.55%	test accuracy: 92.75%
# ------------------ Training Epoch 17 ------------------
# Finished Testing
# Testing accuracy: 93.33 %
# train accuracy: 93.02%	test accuracy: 93.33%
# ------------------ Training Epoch 18 ------------------
# Finished Testing
# Testing accuracy: 93.75 %
# train accuracy: 93.56%	test accuracy: 93.75%
# ------------------ Training Epoch 19 ------------------
# Finished Testing
# Testing accuracy: 94.04 %
# train accuracy: 93.87%	test accuracy: 94.04%
# ------------------ Training Epoch 20 ------------------
# Finished Testing
# Testing accuracy: 94.22 %
# train accuracy: 94.12%	test accuracy: 94.22%
# ------------------ Training Epoch 21 ------------------
# Finished Testing
# Testing accuracy: 94.48 %
# train accuracy: 94.30%	test accuracy: 94.48%
# ------------------ Training Epoch 22 ------------------
# Finished Testing
# Testing accuracy: 94.60 %
# train accuracy: 94.45%	test accuracy: 94.60%
# ------------------ Training Epoch 23 ------------------
# Finished Testing
# Testing accuracy: 94.67 %
# train accuracy: 94.52%	test accuracy: 94.67%
# ------------------ Training Epoch 24 ------------------
# Finished Testing
# Testing accuracy: 94.74 %
# train accuracy: 94.62%	test accuracy: 94.74%
# ------------------ Training Epoch 25 ------------------
# Finished Testing
# Testing accuracy: 94.77 %
# train accuracy: 94.66%	test accuracy: 94.77%
# ------------------ Training Epoch 26 ------------------
# Finished Testing
# Testing accuracy: 94.82 %
# train accuracy: 94.71%	test accuracy: 94.82%
# ------------------ Training Epoch 27 ------------------
# Finished Testing
# Testing accuracy: 94.84 %
# train accuracy: 94.76%	test accuracy: 94.84%
# ------------------ Training Epoch 28 ------------------
# Finished Testing
# Testing accuracy: 94.84 %
# train accuracy: 94.78%	test accuracy: 94.84%
# ------------------ Training Epoch 29 ------------------
# Finished Testing
# Testing accuracy: 94.91 %
# train accuracy: 94.81%	test accuracy: 94.91%
# ------------------ Training Epoch 30 ------------------
# Finished Testing
# Testing accuracy: 94.98 %
# train accuracy: 94.84%	test accuracy: 94.98%
# ------------------ Training Epoch 31 ------------------
# Finished Testing
# Testing accuracy: 95.01 %
# train accuracy: 94.91%	test accuracy: 95.01%
# ------------------ Training Epoch 32 ------------------
# Finished Testing
# Testing accuracy: 95.05 %
# train accuracy: 94.95%	test accuracy: 95.05%
# ------------------ Training Epoch 33 ------------------
# Finished Testing
# Testing accuracy: 95.07 %
# train accuracy: 94.96%	test accuracy: 95.07%
# ------------------ Training Epoch 34 ------------------
# Finished Testing
# Testing accuracy: 95.13 %
# train accuracy: 95.02%	test accuracy: 95.13%
# ------------------ Training Epoch 35 ------------------
# Finished Testing
# Testing accuracy: 95.18 %
# train accuracy: 95.04%	test accuracy: 95.18%
# ------------------ Training Epoch 36 ------------------
# Finished Testing
# Testing accuracy: 95.23 %
# train accuracy: 95.13%	test accuracy: 95.23%
# ------------------ Training Epoch 37 ------------------
# Finished Testing
# Testing accuracy: 95.25 %
# train accuracy: 95.14%	test accuracy: 95.25%
# ------------------ Training Epoch 38 ------------------
# Finished Testing
# Testing accuracy: 95.24 %
# train accuracy: 95.15%	test accuracy: 95.24%
# ------------------ Training Epoch 39 ------------------
# Finished Testing
# Testing accuracy: 95.25 %
# train accuracy: 95.17%	test accuracy: 95.25%
# ------------------ Training Epoch 40 ------------------
# Finished Testing
# Testing accuracy: 95.29 %
# train accuracy: 95.19%	test accuracy: 95.29%
# ------------------ Training Epoch 41 ------------------
# Finished Testing
# Testing accuracy: 95.28 %
# train accuracy: 95.20%	test accuracy: 95.28%
# ------------------ Training Epoch 42 ------------------
# Finished Testing
# Testing accuracy: 95.31 %
# train accuracy: 95.22%	test accuracy: 95.31%
# ------------------ Training Epoch 43 ------------------
# Finished Testing
# Testing accuracy: 95.34 %
# train accuracy: 95.27%	test accuracy: 95.34%
# ------------------ Training Epoch 44 ------------------
# Finished Testing
# Testing accuracy: 95.34 %
# train accuracy: 95.25%	test accuracy: 95.34%
# ------------------ Training Epoch 45 ------------------
# Finished Testing
# Testing accuracy: 95.39 %
# train accuracy: 95.31%	test accuracy: 95.39%
# ------------------ Training Epoch 46 ------------------
# Finished Testing
# Testing accuracy: 95.40 %
# train accuracy: 95.32%	test accuracy: 95.40%
# ------------------ Training Epoch 47 ------------------
# Finished Testing
# Testing accuracy: 95.40 %
# train accuracy: 95.33%	test accuracy: 95.40%
# ------------------ Training Epoch 48 ------------------
# Finished Testing
# Testing accuracy: 95.41 %
# train accuracy: 95.34%	test accuracy: 95.41%
# ------------------ Training Epoch 49 ------------------
# Finished Testing
# Testing accuracy: 95.41 %
# train accuracy: 95.34%	test accuracy: 95.41%
# ------------------ Training Epoch 50 ------------------
# Finished Testing
# Testing accuracy: 95.42 %
# train accuracy: 95.35%	test accuracy: 95.42%
# ------------------ Training Epoch 51 ------------------
# Finished Testing
# Testing accuracy: 95.46 %
# train accuracy: 95.37%	test accuracy: 95.46%
# ------------------ Training Epoch 52 ------------------
# Finished Testing
# Testing accuracy: 95.47 %
# train accuracy: 95.41%	test accuracy: 95.47%
# ------------------ Training Epoch 53 ------------------
# Finished Testing
# Testing accuracy: 95.48 %
# train accuracy: 95.41%	test accuracy: 95.48%
# ------------------ Training Epoch 54 ------------------
# Finished Testing
# Testing accuracy: 95.50 %
# train accuracy: 95.41%	test accuracy: 95.50%
# ------------------ Training Epoch 55 ------------------
# Finished Testing
# Testing accuracy: 95.54 %
# train accuracy: 95.44%	test accuracy: 95.54%
# ------------------ Training Epoch 56 ------------------
# Finished Testing
# Testing accuracy: 95.55 %
# train accuracy: 95.48%	test accuracy: 95.55%
# ------------------ Training Epoch 57 ------------------
# Finished Testing
# Testing accuracy: 95.59 %
# train accuracy: 95.48%	test accuracy: 95.59%
# ------------------ Training Epoch 58 ------------------
# Finished Testing
# Testing accuracy: 95.59 %
# train accuracy: 95.51%	test accuracy: 95.59%
# ------------------ Training Epoch 59 ------------------
# Finished Testing
# Testing accuracy: 95.60 %
# train accuracy: 95.52%	test accuracy: 95.60%
# ------------------ Training Epoch 60 ------------------
# Finished Testing
# Testing accuracy: 95.66 %
# train accuracy: 95.54%	test accuracy: 95.66%
# ------------------ Training Epoch 61 ------------------
# Finished Testing
# Testing accuracy: 95.68 %
# train accuracy: 95.59%	test accuracy: 95.68%
# ------------------ Training Epoch 62 ------------------
# Finished Testing
# Testing accuracy: 95.69 %
# train accuracy: 95.60%	test accuracy: 95.69%
# ------------------ Training Epoch 63 ------------------
# Finished Testing
# Testing accuracy: 95.72 %
# train accuracy: 95.63%	test accuracy: 95.72%
# ------------------ Training Epoch 64 ------------------
# Finished Testing
# Testing accuracy: 95.75 %
# train accuracy: 95.64%	test accuracy: 95.75%
# ------------------ Training Epoch 65 ------------------
# Finished Testing
# Testing accuracy: 95.77 %
# train accuracy: 95.68%	test accuracy: 95.77%
# ------------------ Training Epoch 66 ------------------
# Finished Testing
# Testing accuracy: 95.78 %
# train accuracy: 95.69%	test accuracy: 95.78%
# ------------------ Training Epoch 67 ------------------
# Finished Testing
# Testing accuracy: 95.82 %
# train accuracy: 95.71%	test accuracy: 95.82%
# ------------------ Training Epoch 68 ------------------
# Finished Testing
# Testing accuracy: 95.85 %
# train accuracy: 95.77%	test accuracy: 95.85%
# ------------------ Training Epoch 69 ------------------
# Finished Testing
# Testing accuracy: 95.86 %
# train accuracy: 95.79%	test accuracy: 95.86%
# ------------------ Training Epoch 70 ------------------
# Finished Testing
# Testing accuracy: 95.86 %
# train accuracy: 95.79%	test accuracy: 95.86%
# ------------------ Training Epoch 71 ------------------
# Finished Testing
# Testing accuracy: 95.88 %
# train accuracy: 95.79%	test accuracy: 95.88%
# ------------------ Training Epoch 72 ------------------
# Finished Testing
# Testing accuracy: 95.88 %
# train accuracy: 95.81%	test accuracy: 95.88%
# ------------------ Training Epoch 73 ------------------
# Finished Testing
# Testing accuracy: 95.93 %
# train accuracy: 95.82%	test accuracy: 95.93%
# ------------------ Training Epoch 74 ------------------
# Finished Testing
# Testing accuracy: 95.92 %
# train accuracy: 95.84%	test accuracy: 95.92%
# ------------------ Training Epoch 75 ------------------
# Finished Testing
# Testing accuracy: 95.95 %
# train accuracy: 95.87%	test accuracy: 95.95%
# ------------------ Training Epoch 76 ------------------
# Finished Testing
# Testing accuracy: 95.97 %
# train accuracy: 95.90%	test accuracy: 95.97%
# ------------------ Training Epoch 77 ------------------
# Finished Testing
# Testing accuracy: 95.94 %
# train accuracy: 95.91%	test accuracy: 95.94%
# ------------------ Training Epoch 78 ------------------
# Finished Testing
# Testing accuracy: 95.98 %
# train accuracy: 95.88%	test accuracy: 95.98%
# ------------------ Training Epoch 79 ------------------
# Finished Testing
# Testing accuracy: 96.01 %
# train accuracy: 95.95%	test accuracy: 96.01%
# ------------------ Training Epoch 80 ------------------
# Finished Testing
# Testing accuracy: 96.06 %
# train accuracy: 95.95%	test accuracy: 96.06%
# ------------------ Training Epoch 81 ------------------
# Finished Testing
# Testing accuracy: 96.06 %
# train accuracy: 96.01%	test accuracy: 96.06%
# ------------------ Training Epoch 82 ------------------
# Finished Testing
# Testing accuracy: 96.07 %
# train accuracy: 96.01%	test accuracy: 96.07%
# ------------------ Training Epoch 83 ------------------
# Finished Testing
# Testing accuracy: 96.08 %
# train accuracy: 96.02%	test accuracy: 96.08%
# ------------------ Training Epoch 84 ------------------
# Finished Testing
# Testing accuracy: 96.09 %
# train accuracy: 96.02%	test accuracy: 96.09%
# ------------------ Training Epoch 85 ------------------
# Finished Testing
# Testing accuracy: 96.11 %
# train accuracy: 96.05%	test accuracy: 96.11%
# ------------------ Training Epoch 86 ------------------
# Finished Testing
# Testing accuracy: 96.11 %
# train accuracy: 96.08%	test accuracy: 96.11%
# ------------------ Training Epoch 87 ------------------
# Finished Testing
# Testing accuracy: 96.12 %
# train accuracy: 96.10%	test accuracy: 96.12%
# ------------------ Training Epoch 88 ------------------
# Finished Testing
# Testing accuracy: 96.15 %
# train accuracy: 96.11%	test accuracy: 96.15%
# ------------------ Training Epoch 89 ------------------
# Finished Testing
# Testing accuracy: 96.16 %
# train accuracy: 96.11%	test accuracy: 96.16%
# ------------------ Training Epoch 90 ------------------
# Finished Testing
# Testing accuracy: 96.20 %
# train accuracy: 96.11%	test accuracy: 96.20%
# ------------------ Training Epoch 91 ------------------
# Finished Testing
# Testing accuracy: 96.23 %
# train accuracy: 96.17%	test accuracy: 96.23%
# ------------------ Training Epoch 92 ------------------
# Finished Testing
# Testing accuracy: 96.23 %
# train accuracy: 96.20%	test accuracy: 96.23%
# ------------------ Training Epoch 93 ------------------
# Finished Testing
# Testing accuracy: 96.21 %
# train accuracy: 96.18%	test accuracy: 96.21%
# ------------------ Training Epoch 94 ------------------
# Finished Testing
# Testing accuracy: 96.21 %
# train accuracy: 96.18%	test accuracy: 96.21%
# ------------------ Training Epoch 95 ------------------
# Finished Testing
# Testing accuracy: 96.22 %
# train accuracy: 96.18%	test accuracy: 96.22%
# ------------------ Training Epoch 96 ------------------
# Finished Testing
# Testing accuracy: 96.23 %
# train accuracy: 96.19%	test accuracy: 96.23%
# -
# train epoch: 95
# Finished Training
